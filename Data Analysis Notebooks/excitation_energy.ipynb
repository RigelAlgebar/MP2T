# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# <h1 align="center">Nucleobases</h1>

# %%
eedf_1 = pd.read_excel('EOM-MP2T.xlsx',sheetname='set1_EE_nucleobases', skiprows=1)
eedf_1.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3  EOM-MP2  EOM-MP2T  EOM-CCSD  \
# 0      S0101     Uracil         Cs        1A'   5.8191    5.8048    5.7296
# 1        NaN        NaN        NaN        2A'   6.9856    6.9899    6.8870
# 2        NaN        NaN        NaN       1A''   5.2777    5.3412    5.2360
# 3        NaN        NaN        NaN       2A''   6.6855    6.7640    6.6488
# 4      S0102    Thymine         Cs        1A'   5.7576    5.7318    5.6315
#
#    EOM-MP2.1  EOM-MP2T.1  EOM-MP2.2  ...    MP2 first transition  \
# 0      0.090       0.075      0.090  ...                   0.042
# 1      0.099       0.103      0.099  ...                   0.060
# 2      0.042       0.105      0.042  ...                   0.116
# 3      0.037       0.115      0.037  ...                   0.204
# 4      0.126       0.100      0.126  ...                   0.290
#
#   MP2T first transition  Abs MP2 first transition  Abs MP2T first transition  \
# ...

# %%
#Dataframe for normal errors

err_ee_df_1 = eedf_1[['EOM-MP2.1', 'EOM-MP2T.1']] #We take the specific columns
err_ee_df_1.columns = ['MP2', 'MP2T'] # Now just rename the columns
err_ee_df_1 = err_ee_df_1.dropna() #We ignore the non-values encountered

err_ee_df_1.head() #This juts show the first values of the columns to make sure that we took the right ones
# Out:
#      MP2   MP2T
# 0  0.090  0.075
# 1  0.099  0.103
# 2  0.042  0.105
# 3  0.037  0.115
# 4  0.126  0.100

# %%
#Now just a quick statistical description of the datasets

err_ee_df_1.describe()
# Out:
#              MP2       MP2T
# count  36.000000  36.000000
# mean    0.211250   0.175167
# std     0.104661   0.072293
# min     0.037000   0.052000
# 25%     0.112750   0.123750
# 50%     0.233500   0.166500
# 75%     0.300750   0.232500
# max     0.385000   0.327000

# %%
#Dataframe for absolute errors

abs_ee_df_1 = eedf_1[['EOM-MP2.2', 'EOM-MP2T.2']] #We take the specific columns
abs_ee_df_1.columns = ['Abs MP2', 'Abs MP2T'] # Now just rename the columns
abs_ee_df_1 = abs_ee_df_1.dropna() #We ignore the non-values encountered


abs_ee_df_1.head() #This juts show the first values of the columns to make sure that we took the right ones
# Out:
#    Abs MP2  Abs MP2T
# 0    0.090     0.075
# 1    0.099     0.103
# 2    0.042     0.105
# 3    0.037     0.115
# 4    0.126     0.100

# %%
#Now just a quick statistical description of the datasets

abs_ee_df_1.describe()
# Out:
#          Abs MP2   Abs MP2T
# count  36.000000  36.000000
# mean    0.211250   0.175167
# std     0.104661   0.072293
# min     0.037000   0.052000
# 25%     0.112750   0.123750
# 50%     0.233500   0.166500
# 75%     0.300750   0.232500
# max     0.385000   0.327000

# %%
#Define the bins for the histograms
#Remember, if you use the key word "auto" in the bins parameter, Seaborn will fit the optimal number

bins_err_1 = np.linspace(0, 0.4, 7)
bins_abs_1 = np.linspace(0, 0.4, 7)

# %%
#Define plot size in inches (width, height) & resolution(DPI) and put a white background
fig = plt.figure(figsize=(18, 12), dpi=100)
sns.set_style("white")


#Define the data
hist1 = err_ee_df_1['MP2']
hist2 = err_ee_df_1['MP2T']

#plot data
plt.hist(hist1, bins_err_1, histtype='stepfilled', label='MP2', color='b', normed=True)
plt.hist(hist2, bins_err_1, histtype='stepfilled', alpha=0.5, label='MP2T', color='r', normed=True)

#configure  X axesgure(figsize=(15, 10)


#configure  Y axes


#labels
plt.xlabel("Err (Ev)", size=25)
plt.ylabel("Frequency", size=25)

#define font size
sns.set(font_scale=2.5)

#title
plt.title("Nucleobases EE")



#define font size
sns.set(font_scale=2.5)


plt.legend(loc='upper right')

plt.legend(loc='upper right')
plt.show()

# %%
#Define plot size in inches (width, height) & resolution(DPI) and put a white background
fig = plt.figure(figsize=(18, 12), dpi=100)
sns.set_style("white")


#Define the data
hist3 = abs_ee_df_1['Abs MP2']
hist4 = abs_ee_df_1['Abs MP2T']

#plot data
plt.hist(hist3, bins_abs_1, histtype='stepfilled', label='MP2', color='b')
plt.hist(hist4, bins_abs_1, histtype='stepfilled', alpha=0.5, label='MP2T', color='r')

#configure  X axes


#configure  Y axes


#labels
plt.xlabel("Err (Ev)", size=25)
plt.ylabel("Frequency", size=25)

#define font size 592 
sns.set(font_scale=2.5)

#title
plt.title("Nucleobases EE Abs")

plt.axvline(0.1, color='black', linestyle='dashed')
plt.legend(loc='upper right')
plt.show()

# %%
sns.set_style("white")
fig = plt.figure(figsize=(15, 10))
c1, c2 = sns.color_palette("seismic", 2)


#define font size
sns.set(font_scale=2.5)

#title
plt.title("Nucleobases EE")

sns.kdeplot(err_ee_df_1.MP2, kernel='gau', label='MP2', shade=True, color=c1)
sns.kdeplot(err_ee_df_1.MP2T, kernel='gau',  label='MP2T',shade=True, color=c2)

plt.axvline(0, color='black', linestyle='dashed')
plt.show()

# %%
sns.set_style("whitegrid")
fig = plt.figure(figsize=(15, 10))
plt.axhline(0, color='black')

#define font size
sns.set(font_scale=2.5)

#title
plt.title("Nucleobases EE")


# Draw a nested violinplot and split the violins for easier comparison
viol = sns.violinplot(data=err_ee_df_1, split=True, inner='quartile', palette='seismic')

# %% [markdown]
# <h1 align="center">Biomolecules</h1>

# %%
eedf_2 = pd.read_excel('EOM-MP2T.xlsx',sheetname='set2_other_bio_EE', skiprows=1)
eedf_2.head()
# Out:
#   Unnamed: 0            Unnamed: 1 Unnamed: 2 Unnamed: 3  EOM-MP2  EOM-MP2T  \
# 0      S0201                  HBDI         Cs        1A'   3.4047    3.3956
# 1        NaN                   NaN        NaN        2A'   4.8536    4.8245
# 2        NaN                   NaN        NaN       1A''   4.2210    4.2377
# 3        NaN                   NaN        NaN       2A''   5.1326    5.1232
# 4      S0202  4(5)-methylimidazole         Cs        1A'   6.9456    6.8821
#
#    EOM-CCSD  EOM-MP2.1  EOM-MP2T.1  EOM-MP2.2  ...    Unnamed: 11 Unnamed: 12  \
# 0    3.0474      0.357       0.348      0.357  ...        -0.5984         NaN
# 1    4.5593      0.294       0.265      0.294  ...            NaN         NaN
# 2    4.0324      0.189       0.205      0.189  ...            NaN         NaN
# 3    4.8886      0.244       0.235      0.244  ...            NaN         NaN
# 4    6.7157      0.230       0.166      0.230  ...        -0.4896         NaN
#
# ...

# %%
#Dataframe for normal errors

err_ee_df_2 = eedf_2[['EOM-MP2.1', 'EOM-MP2T.1']] #We take the specific columns
err_ee_df_2.columns = ['MP2', 'MP2T'] # Now just rename the columns
err_ee_df_2 = err_ee_df_2.dropna() #We ignore the non-values encountered

err_ee_df_2.head() #This juts show the first values of the columns to make sure that we took the right ones
# Out:
#      MP2   MP2T
# 0  0.357  0.348
# 1  0.294  0.265
# 2  0.189  0.205
# 3  0.244  0.235
# 4  0.230  0.166

# %%
#Now just a quick statistical description of the datasets

err_ee_df_2.describe()
# Out:
#              MP2       MP2T
# count  22.000000  22.000000
# mean    0.223955   0.160682
# std     0.057138   0.077509
# min     0.142000   0.051000
# 25%     0.189750   0.100750
# 50%     0.220500   0.140500
# 75%     0.243000   0.202250
# max     0.357000   0.348000

# %%
#Dataframe for absolute errors

abs_ee_df_2 = eedf_2[['EOM-MP2.2', 'EOM-MP2T.2']] #We take the specific columns
abs_ee_df_2.columns = ['Abs MP2', 'Abs MP2T'] # Now just rename the columns
abs_ee_df_2 = abs_ee_df_2.dropna() #We ignore the non-values encountered


abs_ee_df_2.head() #This juts show the first values of the columns to make sure that we took the right ones
# Out:
#    Abs MP2  Abs MP2T
# 0    0.357     0.348
# 1    0.294     0.265
# 2    0.189     0.205
# 3    0.244     0.235
# 4    0.230     0.166

# %%
#Now just a quick statistical description of the datasets

abs_ee_df_2.describe()
# Out:
#          Abs MP2   Abs MP2T
# count  22.000000  22.000000
# mean    0.223955   0.160682
# std     0.057138   0.077509
# min     0.142000   0.051000
# 25%     0.189750   0.100750
# 50%     0.220500   0.140500
# 75%     0.243000   0.202250
# max     0.357000   0.348000

# %%
#Define the bins for the histograms
#Remember, if you use the key word "auto" in the bins parameter, Seaborn will fit the optimal number

bins_err_2 = np.linspace(0, 0.4, 6)
bins_abs_2 = np.linspace(0, 0.4, 6)

# %%
#Define plot size in inches (width, height) & resolution(DPI) and put a white background
fig = plt.figure(figsize=(18, 12), dpi=100)
sns.set_style("white")


#Define the data
hist1 = err_ee_df_2['MP2']
hist2 = err_ee_df_2['MP2T']

#plot data
plt.hist(hist1, bins_err_2, histtype='stepfilled', label='MP2', color='b', normed=True)
plt.hist(hist2, bins_err_2, histtype='stepfilled', alpha=0.5, label='MP2T', color='r', normed=True)

#configure  X axesgure(figsize=(15, 10)


#configure  Y axes


#labels
plt.xlabel("Err (Ev)", size=25)
plt.ylabel("Frequency", size=25)

#define font size
sns.set(font_scale=2.5)

#title
plt.title("Biomolecules EE")



#define font size
sns.set(font_scale=2.5)

#title

plt.legend(loc='upper right')

plt.legend(loc='upper right')
plt.show()

# %%
#Define plot size in inches (width, height) & resolution(DPI) and put a white background
fig = plt.figure(figsize=(18, 12), dpi=100)
sns.set_style("white")


#Define the data
hist3 = abs_ee_df_2['Abs MP2']
hist4 = abs_ee_df_2['Abs MP2T']

#plot data
plt.hist(hist3, bins_abs_2, histtype='stepfilled', label='MP2', color='b', normed=True)
plt.hist(hist4, bins_abs_2, histtype='stepfilled', alpha=0.5, label='MP2T', color='r', normed=True)

#configure  X axes


#configure  Y axes


#labels
plt.xlabel("Err (Ev)", size=25)
plt.ylabel("Frequency", size=25)

#define font size 592 
sns.set(font_scale=2.5)

#title
plt.title("Biomolecules EE Abs")

plt.axvline(0.1, color='black', linestyle='dashed')
plt.legend(loc='upper right')
plt.show()

# %%
sns.set_style("white")
fig = plt.figure(figsize=(15, 10))
c1, c2 = sns.color_palette("seismic", 2)


#define font size
sns.set(font_scale=2.5)

#title
plt.title("Biomolecules EE")

sns.kdeplot(err_ee_df_2.MP2, kernel='gau', label='MP2', shade=True, color=c1)
sns.kdeplot(err_ee_df_2.MP2T, kernel='gau',  label='MP2T',shade=True, color=c2)

plt.axvline(0, color='black', linestyle='dashed')
plt.show()

# %%
sns.set_style("whitegrid")
fig = plt.figure(figsize=(15, 10))
plt.axhline(0, color='black')

#define font size
sns.set(font_scale=2.5)

#title
plt.title("Biomolecules EE")


# Draw a nested violinplot and split the violins for easier comparison
viol = sns.violinplot(data=err_ee_df_2, split=True, inner='quartile', palette='seismic')

# %% [markdown]
# <h1 align="center">Quinones</h1>

# %%
eedf_3 = pd.read_excel('EOM-MP2T.xlsx',sheetname='set3_EE_quinones', skiprows=1)
eedf_3.head()
# Out:
#   Unnamed: 0  Unnamed: 1 Unnamed: 2 Unnamed: 3  EOM-CCSD  EOM-MP2  EOM-MP2T  \
# 0     s3mol1         NaN        D2h        1Ag       NaN      NaN       NaN
# 1        NaN         NaN        NaN        2Ag    8.8864   8.9339    8.9743
# 2        NaN         NaN        NaN       1B1g    4.9018   5.1010    4.9437
# 3        NaN         NaN        NaN       2B1g    7.6253   7.6788    7.6918
# 4        NaN         NaN        NaN       1B2g    6.7975   6.7916    6.7892
#
#    EOM-MP2.1  EOM-MP2T.1  EOM-MP2.2  EOM-MP2T.2  MP2 first transition  \
# 0        NaN         NaN        NaN         NaN                   NaN
# 1     0.0475      0.0879     0.0475      0.0879                   NaN
# 2     0.1992      0.0419     0.1992      0.0419                   NaN
# 3     0.0535      0.0665     0.0535      0.0665                   NaN
# 4    -0.0059     -0.0083     0.0059      0.0083                   NaN
#
#    MP2T first transition  Abs MP2 first transition  Abs MP2T first transition
# ...

# %%
#Dataframe for normal errors

err_ee_df_3 = eedf_3[['EOM-MP2.1', 'EOM-MP2T.1']] #We take the specific columns
err_ee_df_3.columns = ['MP2', 'MP2T'] # Now just rename the columns
err_ee_df_3 = err_ee_df_3.dropna() #We ignore the non-values encountered

err_ee_df_3.head() #This juts show the first values of the columns to make sure that we took the right ones
# Out:
#       MP2    MP2T
# 1  0.0475  0.0879
# 2  0.1992  0.0419
# 3  0.0535  0.0665
# 4 -0.0059 -0.0083
# 5  0.1208  0.0639

# %%
#Now just a quick statistical description of the datasets

err_ee_df_3.describe()
# Out:
#               MP2        MP2T
# count  175.000000  175.000000
# mean     0.226318    0.188052
# std      0.113273    0.096066
# min     -0.016500   -0.054500
# 25%      0.145950    0.111000
# 50%      0.208300    0.183800
# 75%      0.318900    0.270850
# max      0.490200    0.414300

# %%
#Dataframe for absolute errors

abs_ee_df_3 = eedf_3[['EOM-MP2.2', 'EOM-MP2T.2']] #We take the specific columns
abs_ee_df_3.columns = ['Abs MP2', 'Abs MP2T'] # Now just rename the columns
abs_ee_df_3 = abs_ee_df_3.dropna() #We ignore the non-values encountered


abs_ee_df_3.head() #This juts show the first values of the columns to make sure that we took the right ones
# Out:
#    Abs MP2  Abs MP2T
# 1   0.0475    0.0879
# 2   0.1992    0.0419
# 3   0.0535    0.0665
# 4   0.0059    0.0083
# 5   0.1208    0.0639

# %%
#Now just a quick statistical description of the datasets

abs_ee_df_3.describe()
# Out:
#           Abs MP2    Abs MP2T
# count  175.000000  175.000000
# mean     0.226624    0.189431
# std      0.112655    0.093300
# min      0.003600    0.008300
# 25%      0.145950    0.111000
# 50%      0.208300    0.183800
# 75%      0.318900    0.270850
# max      0.490200    0.414300

# %%
#Define the bins for the histograms
#Remember, if you use the key word "auto" in the bins parameter, Seaborn will fit the optimal number

bins_err_3 = np.linspace(-0.1, 0.50, 34)
bins_abs_3 = np.linspace(0, 0.50, 17)

# %%
#Define plot size in inches (width, height) & resolution(DPI) and put a white background
fig = plt.figure(figsize=(18, 12), dpi=100)
sns.set_style("white")


#Define the data
hist1 = err_ee_df_3['MP2']
hist2 = err_ee_df_3['MP2T']

#plot data
plt.hist(hist1, bins_err_3, histtype='stepfilled', label='MP2', color='b')
plt.hist(hist2, bins_err_3, histtype='stepfilled', alpha=0.5, label='MP2T', color='r')

#configure  X axesgure(figsize=(15, 10)
plt.ylim(0,16)
plt.xlim(-.1,.55)

#configure  Y axes


#labels
plt.xlabel("Err (Ev)", size=25)
plt.ylabel("Frequency", size=25)

#define font size
sns.set(font_scale=2.5)

#title
plt.title("Quinones EE")



#define font size
sns.set(font_scale=2.5)

#title

plt.legend(loc='upper right')

plt.legend(loc='upper right')
plt.show()

# %%
#Define plot size in inches (width, height) & resolution(DPI) and put a white background
fig = plt.figure(figsize=(18, 12), dpi=100)
sns.set_style("white")


#Define the data
hist3 = abs_ee_df_3['Abs MP2']
hist4 = abs_ee_df_3['Abs MP2T']

#plot data
plt.hist(hist3, bins_abs_3, histtype='stepfilled', label='MP2', color='b')
plt.hist(hist4, bins_abs_3, histtype='stepfilled', alpha=0.5, label='MP2T', color='r')

#configure  X axes


#configure  Y axes
plt.xlim(0,.55)

#labels
plt.xlabel("Err (Ev)", size=25)
plt.ylabel("Frequency", size=25)

#define font size 592 
sns.set(font_scale=2.5)

#title
plt.title("Quinones EE Abs")

plt.axvline(0.1, color='black', linestyle='dashed')
plt.legend(loc='upper right')
plt.show()

# %%
sns.set_style("white")
fig = plt.figure(figsize=(15, 10))
c1, c2 = sns.color_palette("seismic", 2)


#define font size
sns.set(font_scale=2.5)

#title
plt.title("Quinones EE")

sns.kdeplot(err_ee_df_3.MP2, kernel='gau', label='MP2', shade=True, color=c1)
sns.kdeplot(err_ee_df_3.MP2T, kernel='gau',  label='MP2T',shade=True, color=c2)

plt.axvline(0, color='black', linestyle='dashed')
plt.show()

# %%
sns.set_style("whitegrid")
fig = plt.figure(figsize=(15, 10))
plt.axhline(0, color='black')

#define font size
sns.set(font_scale=2.5)

#title
plt.title("Quinones EE")


# Draw a nested violinplot and split the violins for easier comparison
viol = sns.violinplot(data=err_ee_df_3, split=True, inner='quartile', palette='seismic')

# %% [markdown]
# <h1 align="center">Polyenes</h1>

# %%
eedf_4 = pd.read_excel('EOM-MP2T.xlsx',sheetname='set4_EE_polyenes', skiprows=1)
eedf_4.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3  EOM-CCSD  EOM-MP2  EOM-MP2T  \
# 0     s4mol1   ethylene        D2h        1Ag   12.9935  13.0075   12.8739
# 1        NaN        NaN        NaN        2Ag   13.9378  13.8679   13.8024
# 2        NaN        NaN        NaN       1B1g   10.9890  10.8957   10.8089
# 3        NaN        NaN        NaN       2B1g   15.1565  15.0869   14.9977
# 4        NaN        NaN        NaN       1B2g    9.6783   9.6080    9.5171
#
#    EOM-MP2.1  EOM-MP2T.1  EOM-MP2.2  EOM-MP2T.2  MP2 first transition  \
# 0     0.0140     -0.1196     0.0140      0.1196               -0.1978
# 1    -0.0699     -0.1354     0.0699      0.1354               -0.1531
# 2    -0.0933     -0.1801     0.0933      0.1801               -0.0887
# 3    -0.0696     -0.1588     0.0696      0.1588               -0.0332
# 4    -0.0703     -0.1612     0.0703      0.1612                0.0121
#
#    MP2T first transition  Abs MP2 first transition  Abs MP2T first transition
# ...

# %%
#Dataframe for normal errors

err_ee_df_4 = eedf_4[['EOM-MP2.1', 'EOM-MP2T.1']] #We take the specific columns
err_ee_df_4.columns = ['MP2', 'MP2T'] # Now just rename the columns
err_ee_df_4 = err_ee_df_4.dropna() #We ignore the non-values encountered

err_ee_df_4.head() #This juts show the first values of the columns to make sure that we took the right ones
# Out:
#       MP2    MP2T
# 0  0.0140 -0.1196
# 1 -0.0699 -0.1354
# 2 -0.0933 -0.1801
# 3 -0.0696 -0.1588
# 4 -0.0703 -0.1612

# %%
#Now just a quick statistical description of the datasets

err_ee_df_4.describe()
# Out:
#              MP2       MP2T
# count  72.000000  72.000000
# mean    0.032610  -0.048329
# std     0.121573   0.095810
# min    -0.265500  -0.259100
# 25%    -0.069675  -0.134950
# 50%     0.052200  -0.032800
# 75%     0.135650   0.024350
# max     0.238300   0.131800

# %%
#Dataframe for absolute errors

abs_ee_df_4 = eedf_4[['EOM-MP2.2', 'EOM-MP2T.2']] #We take the specific columns
abs_ee_df_4.columns = ['Abs MP2', 'Abs MP2T'] # Now just rename the columns
abs_ee_df_4 = abs_ee_df_4.dropna() #We ignore the non-values encountered


abs_ee_df_4.head() #This juts show the first values of the columns to make sure that we took the right ones
# Out:
#    Abs MP2  Abs MP2T
# 0   0.0140    0.1196
# 1   0.0699    0.1354
# 2   0.0933    0.1801
# 3   0.0696    0.1588
# 4   0.0703    0.1612

# %%
#Now just a quick statistical description of the datasets

abs_ee_df_4.describe()
# Out:
#          Abs MP2   Abs MP2T
# count  72.000000  72.000000
# mean    0.108049   0.084421
# std     0.063399   0.065734
# min     0.005000   0.002700
# 25%     0.062175   0.030050
# 50%     0.098000   0.062250
# 75%     0.154050   0.134950
# max     0.265500   0.259100

# %%
#Define the bins for the histograms
#Remember, if you use the key word "auto" in the bins parameter, Seaborn will fit the optimal number

bins_err_4 = np.linspace(-0.3, 0.3, 14)
bins_abs_4 = np.linspace(0, 0.7, 7)

# %%
#Define plot size in inches (width, height) & resolution(DPI) and put a white background
fig = plt.figure(figsize=(18, 12), dpi=100)
sns.set_style("white")


#Define the data
hist1 = err_ee_df_4['MP2']
hist2 = err_ee_df_4['MP2T']

#plot data
plt.hist(hist1, bins_err_4, histtype='stepfilled', label='MP2', color='b')
plt.hist(hist2, bins_err_4, histtype='stepfilled', alpha=0.5, label='MP2T', color='r')

#configure  X axesgure(figsize=(15, 10)


#configure  Y axes


#labels
plt.xlabel("Err (Ev)", size=25)
plt.ylabel("Frequency", size=25)

#define font size
sns.set(font_scale=2.5)

#title
plt.title("Polyenes EE")



#define font size
sns.set(font_scale=2.5)

#title

plt.legend(loc='upper right')

plt.legend(loc='upper right')
plt.show()

# %%
#Define plot size in inches (width, height) & resolution(DPI) and put a white background
fig = plt.figure(figsize=(18, 12), dpi=100)
sns.set_style("white")


#Define the data
hist3 = abs_ee_df_4['Abs MP2']
hist4 = abs_ee_df_4['Abs MP2T']

#plot data
plt.hist(hist3, bins_abs_4, histtype='stepfilled', label='MP2', color='b')
plt.hist(hist4, bins_abs_4, histtype='stepfilled', alpha=0.5, label='MP2T', color='r')

#configure  X axes


#configure  Y axes


#labels
plt.xlabel("Err (Ev)", size=25)
plt.ylabel("Frequency", size=25)

#define font size 592 
sns.set(font_scale=2.5)

#title
plt.title("Polyenes EE Abs")

plt.axvline(0.1, color='black', linestyle='dashed')
plt.legend(loc='upper right')
plt.show()

# %%
sns.set_style("white")
fig = plt.figure(figsize=(15, 10))
c1, c2 = sns.color_palette("seismic", 2)


#define font size
sns.set(font_scale=2.5)

#title
plt.title("Polyenes EE")

sns.kdeplot(err_ee_df_4.MP2, kernel='gau', label='MP2', shade=True, color=c1)
sns.kdeplot(err_ee_df_4.MP2T, kernel='gau',  label='MP2T',shade=True, color=c2)

plt.axvline(0, color='black', linestyle='dashed')
plt.show()

# %%
sns.set_style("whitegrid")
fig = plt.figure(figsize=(15, 10))
plt.axhline(0, color='black')

#define font size
sns.set(font_scale=2.5)

#title
plt.title("Polyenes EE")


# Draw a nested violinplot and split the violins for easier comparison
viol = sns.violinplot(data=err_ee_df_4, split=True, inner='quartile', palette='seismic')

# %% [markdown]
# <h1 align="center">Small Molecules</h1>

# %%
eedf_5 = pd.read_excel('EOM-MP2T.xlsx',sheetname='set5_EE_small', skiprows=1)
eedf_5.head()
# Out:
#   Unnamed: 0  Unnamed: 1 Unnamed: 2 Unnamed: 3  EOM-CCSD  EOM-MP2  EOM-MP2T  \
# 0     s5mol1         NaN        C2v        1A1    7.2065   7.2692    7.1933
# 1        NaN         NaN        NaN        2A1    9.0348   8.9900    8.9622
# 2        NaN         NaN        NaN        1A2    7.1729   7.2578    7.1535
# 3        NaN         NaN        NaN        2A2    8.0727   8.1654    8.0580
# 4        NaN         NaN        NaN        1B1    5.7637   5.7144    5.6914
#
#    EOM-MP2.1  EOM-MP2T.1  EOM-MP2.2  EOM-MP2T.2  MP2 first transition  \
# 0     0.0627     -0.0132     0.0627      0.0132                   NaN
# 1    -0.0448     -0.0726     0.0448      0.0726                   NaN
# 2     0.0849     -0.0194     0.0849      0.0194                   NaN
# 3     0.0927     -0.0147     0.0927      0.0147                   NaN
# 4    -0.0493     -0.0723     0.0493      0.0723                   NaN
#
#    MP2T first transition  Abs MP2 first transition Abs MP2T first transition
# ...

# %%
#Dataframe for normal errors

err_ee_df_5 = eedf_5[['EOM-MP2.1', 'EOM-MP2T.1']] #We take the specific columns
err_ee_df_5.columns = ['MP2', 'MP2T'] # Now just rename the columns
err_ee_df_5 = err_ee_df_5.dropna() #We ignore the non-values encountered

err_ee_df_5.head() #This juts show the first values of the columns to make sure that we took the right ones
# Out:
#       MP2    MP2T
# 0  0.0627 -0.0132
# 1 -0.0448 -0.0726
# 2  0.0849 -0.0194
# 3  0.0927 -0.0147
# 4 -0.0493 -0.0723

# %%
#Now just a quick statistical description of the datasets

err_ee_df_5.describe()
# Out:
#               MP2        MP2T
# count  273.000000  273.000000
# mean     0.123067    0.061826
# std      0.140966    0.130077
# min     -0.248500   -0.258800
# 25%      0.000100   -0.029200
# 50%      0.135900    0.066700
# 75%      0.219800    0.144700
# max      0.479000    0.425600

# %%
#Dataframe for absolute errors

abs_ee_df_5 = eedf_5[['EOM-MP2.2', 'EOM-MP2T.2']] #We take the specific columns
abs_ee_df_5.columns = ['Abs MP2', 'Abs MP2T'] # Now just rename the columns
abs_ee_df_5 = abs_ee_df_5.dropna() #We ignore the non-values encountered


abs_ee_df_5.head() #This juts show the first values of the columns to make sure that we took the right ones
# Out:
#    Abs MP2  Abs MP2T
# 0   0.0627    0.0132
# 1   0.0448    0.0726
# 2   0.0849    0.0194
# 3   0.0927    0.0147
# 4   0.0493    0.0723

# %%
#Now just a quick statistical description of the datasets

abs_ee_df_5.describe()
# Out:
#           Abs MP2    Abs MP2T
# count  273.000000  273.000000
# mean     0.152694    0.115195
# std      0.108035    0.086243
# min      0.000000    0.000000
# 25%      0.059800    0.045600
# 50%      0.143700    0.103200
# 75%      0.228700    0.166100
# max      0.479000    0.425600

# %%
#Define the bins for the histograms
#Remember, if you use the key word "auto" in the bins parameter, Seaborn will fit the optimal number

bins_err_5 = np.linspace(-0.26, 0.5, 54)
bins_abs_5 = np.linspace(0, 0.5, 27)

# %%
#Define plot size in inches (width, height) & resolution(DPI) and put a white background
fig = plt.figure(figsize=(18, 12), dpi=100)
sns.set_style("white")


#Define the data
hist1 = err_ee_df_5['MP2']
hist2 = err_ee_df_5['MP2T']

#plot data
plt.hist(hist1, bins_err_5, histtype='stepfilled', label='MP2', color='b')
plt.hist(hist2, bins_err_5, histtype='stepfilled', alpha=0.5, label='MP2T', color='r')

#configure  X axesgure(figsize=(15, 10)
plt.xlim(-0.3,.5)

#configure  Y axes


#labels
plt.xlabel("Err (Ev)", size=25)
plt.ylabel("Frequency", size=25)

#define font size
sns.set(font_scale=2.5)

#title
plt.title("Small Molecules EE")



#define font size
sns.set(font_scale=2.5)

#title

plt.legend(loc='upper right')

plt.legend(loc='upper right')
plt.show()

# %%
#Define plot size in inches (width, height) & resolution(DPI) and put a white background
fig = plt.figure(figsize=(18, 12), dpi=100)
sns.set_style("white")


#Define the data
hist3 = abs_ee_df_5['Abs MP2']
hist4 = abs_ee_df_5['Abs MP2T']

#plot data
plt.hist(hist3, bins_abs_5, histtype='stepfilled', label='MP2', color='b')
plt.hist(hist4, bins_abs_5, histtype='stepfilled', alpha=0.5, label='MP2T', color='r')

#configure  X axes


#configure  Y axes


#labels
plt.xlabel("Err (Ev)", size=25)
plt.ylabel("Frequency", size=25)

#define font size 592 
sns.set(font_scale=2.5)

#title
plt.title("Small Molecules EE Abs")

plt.axvline(0.1, color='black', linestyle='dashed')
plt.legend(loc='upper right')
plt.show()

# %%
sns.set_style("white")
fig = plt.figure(figsize=(15, 10))
c1, c2 = sns.color_palette("seismic", 2)


#define font size
sns.set(font_scale=2.5)

#title
plt.title("Small MOlecules EE")

sns.kdeplot(err_ee_df_5.MP2, kernel='gau', label='MP2', shade=True, color=c1)
sns.kdeplot(err_ee_df_5.MP2T, kernel='gau',  label='MP2T',shade=True, color=c2)

plt.axvline(0, color='black', linestyle='dashed')
plt.show()

# %%
sns.set_style("whitegrid")
fig = plt.figure(figsize=(15, 10))
plt.axhline(0, color='black')

#define font size
sns.set(font_scale=2.5)

#title
plt.title("Small Molecules EE")


# Draw a nested violinplot and split the violins for easier comparison
viol = sns.violinplot(data=err_ee_df_5, split=True, inner='quartile', palette='seismic')

# %% [markdown]
# <h1 align="center">Universal Data Set</h1>

# %%
# We define here the data sets that we are going to fuse
frames = [err_ee_df_1, err_ee_df_2, err_ee_df_3, err_ee_df_4, err_ee_df_5]

# %%
# Now we create the universial dataframe
universal_err_ee_df = pd.concat(frames)

# %%
# Quick view of the universial dataframe
universal_err_ee_df.head()
# Out:
#      MP2   MP2T
# 0  0.090  0.075
# 1  0.099  0.103
# 2  0.042  0.105
# 3  0.037  0.115
# 4  0.126  0.100

# %%
# Quick statistical description of the universial dataframe
universal_err_ee_df.describe()
# Out:
#               MP2        MP2T
# count  578.000000  578.000000
# mean     0.152393    0.097144
# std      0.141791    0.136731
# min     -0.265500   -0.259100
# 25%      0.060475    0.000600
# 50%      0.158300    0.104050
# 75%      0.244525    0.191350
# max      0.490200    0.425600

# %%
# Now we do the same for the absolute values
frames2 = [abs_ee_df_1, abs_ee_df_2, abs_ee_df_3, abs_ee_df_4, abs_ee_df_5]

# %%
# Now we create the universial dataframe
universal_abs_ee_df = pd.concat(frames2)

# %%
# Quick view of the universial dataframe for abs values
universal_abs_ee_df.head()
# Out:
#    Abs MP2  Abs MP2T
# 0    0.090     0.075
# 1    0.099     0.103
# 2    0.042     0.105
# 3    0.037     0.115
# 4    0.126     0.100

# %%
universal_abs_ee_df.describe()
# Out:
#           Abs MP2    Abs MP2T
# count  578.000000  578.000000
# mean     0.175876    0.139304
# std      0.111278    0.093324
# min      0.000000    0.000000
# 25%      0.087150    0.066625
# 50%      0.163750    0.125800
# 75%      0.246475    0.194625
# max      0.490200    0.425600

# %%
universal_stat = universal_err_ee_df.describe()

# %%
stat_tex= universal_stat.to_latex()

# %%
print stat_tex
# Out:
# \begin{tabular}{lrr}
# \toprule
# {} &         MP2 &        MP2T \\
# \midrule
# count &  578.000000 &  578.000000 \\
# mean  &    0.152393 &    0.097144 \\
# std   &    0.141791 &    0.136731 \\
# min   &   -0.265500 &   -0.259100 \\
# 25\%   &    0.060475 &    0.000600 \\
# 50\%   &    0.158300 &    0.104050 \\
# 75\%   &    0.244525 &    0.191350 \\
# max   &    0.490200 &    0.425600 \\
# \bottomrule
# \end{tabular}

# %%
#Define the bins for the histograms
#Remember, if you use the key word "auto" in the bins parameter, Seaborn will fit the optimal number

univ_bins_err = np.linspace(-0.3, 0.50, 116)
univ_bins_abs = np.linspace(0, 0.50, 58)

# %%
#Define plot size in inches (width, height) & resolution(DPI) and put a white background
fig = plt.figure(figsize=(15, 10), dpi=100)
sns.set_style("white")


#Define the data
hist1 = universal_err_ee_df['MP2']
hist2 = universal_err_ee_df['MP2T']

#plot data
plt.hist(hist1, univ_bins_err, histtype='stepfilled', label='MP2', color='b')
plt.hist(hist2, univ_bins_err, histtype='stepfilled', alpha=0.5, label='MP2T', color='r')

#configure  X axes
plt.xlim(-.3,.55)

#configure  Y axes
plt.ylim(0,20)

#labels
plt.xlabel("Err (Ev)", size=25)
plt.ylabel("Frequency", size=25)

#define font size
sns.set(font_scale=2.5)

#title
plt.title("Universal EE")

plt.axvline(0, color='black', linestyle='dashed')
plt.legend(loc='upper right')
plt.show()

# %%
#Define plot size in inches (width, height) & resolution(DPI) and put a white background
fig = plt.figure(figsize=(15, 10), dpi=100)
sns.set_style("white")


#Define the data
hist3 = universal_abs_ee_df['Abs MP2']
hist4 = universal_abs_ee_df['Abs MP2T']

#plot data
plt.hist(hist3, univ_bins_abs, histtype='stepfilled', label='MP2', color='b')
plt.hist(hist4, univ_bins_abs, histtype='stepfilled', alpha=0.5, label='MP2T', color='r')

#configure  X axes


#configure  Y axes
plt.ylim(0,40)

#labels
plt.xlabel("Err (Ev)", size=25)
plt.ylabel("Frequency", size=25)

#define font size 592 
sns.set(font_scale=2.5)

#title
plt.title("Universal EE Abs")

plt.axvline(0.1, color='black', linestyle='dashed')
plt.legend(loc='upper right')
plt.show()

# %%
sns.set_style("white")
fig = plt.figure(figsize=(15, 10))
c1, c2 = sns.color_palette("seismic", 2)
plt.yticks([])


plt.ylim(0,3)


#define font size
sns.set(font_scale=2.5)

#title
plt.title("Universal EE")
plt.xlabel("Err (Ev)", size=25)
plt.ylabel("Gaussian KDE", size=25)


sns.kdeplot(universal_err_ee_df.MP2, kernel='gau', label='MP2', shade=True, color=c1)
sns.kdeplot(universal_err_ee_df.MP2T, kernel='gau',  label='MP2T',shade=True, color=c2)

plt.axvline(0, color='black', linestyle='dashed')
plt.show()

# %%
sns.set_style("whitegrid")
fig = plt.figure(figsize=(15, 10))
plt.axhline(0, color='black')

#define font size
sns.set(font_scale=2.5)

#title
plt.title("Universal EE")
plt.xlabel("Method", size=25)
plt.ylabel("Err (Ev)", size=25)

# Draw a nested violinplot and split the violins for easier comparison
viol = sns.violinplot(data=universal_err_ee_df, split=True, inner='quartile', palette='seismic')
